# %%
# %run functions.ipynb

np.set_printoptions(precision=3)
np.random.seed(42)

# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /pio/scratch/1/i272955/anaconda3/envs/master/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['flatten', 'clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, X_test, y_train, y_test = load_train_and_test_parts()
print("Train and test sizes: {} {}".format(X_train.shape, X_test.shape))
print("(1, 0) labels count in train test: {} {}".format((np.count_nonzero(y_train==1), np.count_nonzero(y_train==0)), 
                                                        (np.count_nonzero(y_test==1), np.count_nonzero(y_test==0))))
standarizer = StandardScaler().fit(X_train)
X_std_train = standarizer.transform(X_train)
X_std_test = standarizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-34d01d0e689c> in <module>
# ----> 1 X_train, X_test, y_train, y_test = load_train_and_test_parts()
#       2 print("Train and test sizes: {} {}".format(X_train.shape, X_test.shape))
#       3 print("(1, 0) labels count in train test: {} {}".format((np.count_nonzero(y_train==1), np.count_nonzero(y_train==0)),
#       4                                                         (np.count_nonzero(y_test==1), np.count_nonzero(y_test==0))))
#       5 standarizer = StandardScaler().fit(X_train)
#
# <ipython-input-42-50374587fc36> in load_train_and_test_parts()
#       4
#       5 def load_train_and_test_parts():
# ----> 6     X_train = load_file("data/microarray_train.csv")
#       7     X_test = load_file("data/microarray_test.csv")
#       8     y_train = load_file("data/labels_train.csv")
#
# ...

# %%
from sklearn.neighbors import NearestCentroid
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# %%
for thresh in np.linspace(0, 5, 20):
    clf = fit_clf(NearestCentroid(shrink_threshold=thresh), X_train, y_train, X_test, y_test, "NSC")

# %%
for thresh in np.linspace(0, 5, 20):
    clf = fit_clf(NearestCentroid(shrink_threshold=thresh), X_std_train, y_train, X_std_test, y_test, "NSC")

# %%
clf = fit_clf(LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr'), X_train, y_train, X_test, y_test, "LDA")

# %%
clf = fit_clf(LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr'), X_std_train, y_train, X_std_test, y_test, "LDA")
